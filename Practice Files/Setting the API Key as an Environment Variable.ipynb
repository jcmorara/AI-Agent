# %%
import os

# %%
os.environ.items()

# %%
for key, value in os.environ.items():
    print(f"{key}:{value}")
# Out:
# ALLUSERSPROFILE:C:\ProgramData
# APPDATA:C:\Users\Admin\AppData\Roaming
# COMMONPROGRAMFILES:C:\Program Files\Common Files
# COMMONPROGRAMFILES(X86):C:\Program Files (x86)\Common Files
# COMMONPROGRAMW6432:C:\Program Files\Common Files
# COMPUTERNAME:DESKTOP-0NJ7G2E
# COMSPEC:C:\WINDOWS\system32\cmd.exe
# CONDA_PREFIX:C:\Users\Admin\anaconda3
# DRIVERDATA:C:\Windows\System32\Drivers\DriverData
# EFC_1880_1592913036:1
# HOMEDRIVE:C:
# HOMEPATH:\Users\Admin
# IPY_INTERRUPT_EVENT:2544
# JPY_INTERRUPT_EVENT:2544
# JPY_PARENT_PID:1932
# JPY_SESSION_NAME:C:\Users\Admin\Setting the API Key as an Environment Variable.ipynb
# LOCALAPPDATA:C:\Users\Admin\AppData\Local
# LOGONSERVER:\\DESKTOP-0NJ7G2E
# NUMBER_OF_PROCESSORS:8
# ONEDRIVE:C:\Users\Admin\OneDrive
# ONEDRIVECONSUMER:C:\Users\Admin\OneDrive
# OS:Windows_NT
# ...

# %%
os.environ['OPEN_API_KEY'] = '...'

# %%
# %load_ext dotenv
# %dotenv
