# %%
from langchain_core.prompts import PromptTemplate

# %%
TEMPLATE = '''
Sytem:
{description}

Human:
I've recently adopted a {pet}.
Could you suggest some {pet} names?
'''

# %%
prompt_template = PromptTemplate.from_template(template = TEMPLATE)

# %%
prompt_template
# Out:
# PromptTemplate(input_variables=['description', 'pet'], input_types={}, partial_variables={}, template="\nSytem:\n{description}\n\nHuman:\nI've recently adopted a {pet}.\nCould you suggest some {pet} names?\n")

# %%
prompt_value = prompt_template.invoke({'description':''' The chatbot should reluctantly answers questions 
with sarcastic responses. ''', 
                                      'pet': 'dog'})

# %%
prompt_value
# Out:
# StringPromptValue(text="\nSytem:\n The chatbot should reluctantly answers questions \nwith sarcastic responses. \n\nHuman:\nI've recently adopted a dog.\nCould you suggest some dog names?\n")

# %%
print(prompt_value.text)
# Out:
# Sytem:
#  The chatbot should reluctantly answers questions
# with sarcastic responses.
#
# Human:
# I've recently adopted a dog.
# Could you suggest some dog names?
